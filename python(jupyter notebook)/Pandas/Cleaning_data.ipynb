# %% [markdown]
# # Cleaning Data
# - Companies sorted csv file link - [Click here](https://drive.google.com/file/d/1Hnc5wpuPvVDWL-vZOY8BJFj2EWFkfSV0/view?usp=drive_link)

# %%
import pandas as pd

# %%
df = pd.read_csv("companies_sorted.csv")
df
# Out:
#          Unnamed: 0                            name  \
# 0           5872184                             ibm
# 1           4425416       tata consultancy services
# 2             21074                       accenture
# 3           2309813                         us army
# 4           1558607                              ey
# ...             ...                             ...
# 7173421     1494427              certiport vouchers
# 7173422     1494429          black tiger fight club
# 7173423     4768462      catholic bishop of chicago
# 7173424     1494436             medexo robotics ltd
# 7173425     2842728  dynamic controls solutions inc
#
#                                domain  year founded  \
# 0                             ibm.com        1911.0
# 1                             tcs.com        1968.0
# 2                       accenture.com        1989.0
# 3                          goarmy.com        1800.0
# 4                              ey.com        1989.0
# ...

# %% [markdown]
# ### Dropping missing data

# %%
df.dropna(inplace=True) # deletes rows i.e. data

# %%
df
# Out:
#          Unnamed: 0                                name              domain  \
# 0           5872184                                 ibm             ibm.com
# 1           4425416           tata consultancy services             tcs.com
# 2             21074                           accenture       accenture.com
# 3           2309813                             us army          goarmy.com
# 4           1558607                                  ey              ey.com
# ...             ...                                 ...                 ...
# 7173404     5101935                   squad sp. z o. o.        squad.com.pl
# 7173411     4768458  fuller, hadeed, & ros-planas, pllc          fhrlaw.com
# 7173416     3515286                     fit plus s.r.o.          fitplus.sk
# 7173417     5481997                          coriex srl           coriex.it
# 7173422     1494429              black tiger fight club  blacktigerclub.com
#
# ...

# %%
df1 = pd.read_csv("companies_sorted.csv")
df1
# Out:
#          Unnamed: 0                            name  \
# 0           5872184                             ibm
# 1           4425416       tata consultancy services
# 2             21074                       accenture
# 3           2309813                         us army
# 4           1558607                              ey
# ...             ...                             ...
# 7173421     1494427              certiport vouchers
# 7173422     1494429          black tiger fight club
# 7173423     4768462      catholic bishop of chicago
# 7173424     1494436             medexo robotics ltd
# 7173425     2842728  dynamic controls solutions inc
#
#                                domain  year founded  \
# 0                             ibm.com        1911.0
# 1                             tcs.com        1968.0
# 2                       accenture.com        1989.0
# 3                          goarmy.com        1800.0
# 4                              ey.com        1989.0
# ...

# %%
df1.dropna(axis=1,inplace=True) # deletes column where missing values exist

# %%
df1
# Out:
#          Unnamed: 0 size range  \
# 0           5872184     10001+
# 1           4425416     10001+
# 2             21074     10001+
# 3           2309813     10001+
# 4           1558607     10001+
# ...             ...        ...
# 7173421     1494427     1 - 10
# 7173422     1494429     1 - 10
# 7173423     4768462     1 - 10
# 7173424     1494436     1 - 10
# 7173425     2842728     1 - 10
#
#                                               linkedin url  \
# 0                                 linkedin.com/company/ibm
# 1           linkedin.com/company/tata-consultancy-services
# 2                           linkedin.com/company/accenture
# 3                             linkedin.com/company/us-army
# 4                       linkedin.com/company/ernstandyoung
# ...                                                    ...
# 7173421            linkedin.com/company/certiport-vouchers
# 7173422         linkedin.com/company/black-tiger-club-hero
# ...

# %% [markdown]
# ### Filling up NAN value with certain pre-defined value

# %%
df3 = pd.read_csv("companies_sorted.csv")
df3
# Out:
#          Unnamed: 0                            name  \
# 0           5872184                             ibm
# 1           4425416       tata consultancy services
# 2             21074                       accenture
# 3           2309813                         us army
# 4           1558607                              ey
# ...             ...                             ...
# 7173421     1494427              certiport vouchers
# 7173422     1494429          black tiger fight club
# 7173423     4768462      catholic bishop of chicago
# 7173424     1494436             medexo robotics ltd
# 7173425     2842728  dynamic controls solutions inc
#
#                                domain  year founded  \
# 0                             ibm.com        1911.0
# 1                             tcs.com        1968.0
# 2                       accenture.com        1989.0
# 3                          goarmy.com        1800.0
# 4                              ey.com        1989.0
# ...

# %%
df3.fillna("ADITYA",inplace=True)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_20620\3501743868.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'ADITYA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df3.fillna("ADITYA",inplace=True)

# %%
df3[50:100]
# Out:
#     Unnamed: 0                                               name  \
# 50     3243805                                huawei technologies
# 51     5486571                                               dell
# 52     1704309                                                gsk
# 53     5058468                                          honeywell
# 54     1360249                                                sap
# 55     3737260                                       schlumberger
# 56     4985291                                    lockheed martin
# 57     4083731                   ayatama energi, trisco nusantara
# 58     5842173                                                abb
# 59     4112520                       american center of krasnodar
# 60     2187941                                          starbucks
# 61     3936147  promobroker agente de seguros y de fianzas s a...
# 62     4107042                                     morgan stanley
# ...
